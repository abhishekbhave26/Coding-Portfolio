# %%
if (3>4):
    print("It is true")
elif(5>4):
    print("5>4")
else:
    print("not true")
# Out:
# 5>4

# %%
for a in range(0,3):
    print(a)
# Out:
# 0
# 1
# 2

# %%
myList=[(1,2,3),(3,4,0),(5,7,6),(2,2,8)]

# %%
for a,b,c in myList:
    print (b)
# Out:
# 2
# 4
# 7
# 2

# %%
d={"k1":1,"k2":2,"k3":3}

# %%
for key,value in d.items():
    print (key)
# Out:
# k1
# k2
# k3

# %%
x=1
while(x<5):
    print(f"The value of x is {x}")
# Out:
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# The value of x is 1
# ...

# %%
x=2
while(x<5):
    print(f"The value of x is {x}")
    x=x+1
else:
    print("X is greater than 5" )
# Out:
# The value of x is 2
# The value of x is 3
# The value of x is 4
# X is greater than 5
